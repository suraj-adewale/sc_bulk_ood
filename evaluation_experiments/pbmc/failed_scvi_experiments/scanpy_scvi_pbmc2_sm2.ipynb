# %% [markdown]
# This is the tutorial from scanpy using pbmc 3K.
# https://scanpy-tutorials.readthedocs.io/en/latest/pbmc3k.html

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import celltypist
from celltypist import models

import os


res_name = "pbmc_rep2_sm2"
exp_str = "pbmc2"
method_str = "Smart-seq2"

sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_header()
sc.settings.set_figure_params(dpi=80, facecolor='white')

## download celltypist models
# get the low-immune (low-level on ontology, high-resolution)
model_str = 'Immune_All_Low.pkl'
models.download_models(model = [model_str])
# Out:
# 📂 Storing models in /beevol/home/davidson/.celltypist/data/models
# 💾 Total models to download: 1
# ⏩ Skipping [1/1]: Immune_All_Low.pkl (file exists)
# scanpy==1.8.2 anndata==0.7.8 umap==0.5.2 numpy==1.19.5 scipy==1.7.1 pandas==1.3.3 scikit-learn==1.0 statsmodels==0.13.0 python-igraph==0.9.8 louvain==0.7.1 pynndescent==0.5.5

# %% [markdown]
# ## Open files

# %%
data_path = f"{os.getcwd()}/../../data/single_cell_data/GSE132044/sm2_hg19/"

results_file = f"{data_path}/{res_name}.h5ad"

adata = sc.read_10x_mtx(
    data_path,                               # the directory with the `.mtx` file
    var_names='gene_symbols',                # use gene symbols for the variable names (variables-axis index)
    cache=True)                              # write a cache file for faster subsequent reading

adata.var_names_make_unique()  # this is unnecessary if using `var_names='gene_ids'` in `sc.read_10x_mtx`
# Out:
# ... reading from cache file cache/beevol-home-davidson-checkouts-sc_bulk_ood-evaluation_experiments-pbmc-..-..-data-single_cell_data-GSE132044-sm2_hg19-matrix.h5ad

# %%
# make cell type specific marker annotation

genes_annot_dict = {
    'CD14': ['CD14 (CD14 Mono)'],
    'LYZ': ['LYZ (CD14 Mono)'],
    'FCGR3A': ['FCGR3A (CD16 Mono)'],
    'MS4A7': ['MS4A7 (CD16 Mono)'],
    'FCER1A': ['FCER1A (Dendritic)'],
    'CST3': ['CST3 (Dendritic)'],
    'GNLY': ['GNLY (NK)'],
    'NKG7': ['NKG7 (NK)'],
    'MS4A1': ['MS4A1 (B cell)'],
    'CD79A': ['CD79A (B cell)'],
    'IL7R': ['IL7R (CD4T)'],
    'CCR7': ['CCR7 (Naive CD4T)'],
    'S100A4': ['S100A4 (Memory CD4T)'],
    'CD8A': ['CD8A (CD8 T)'],
    'PPBP': ['PPBP (Megak)']
}



# Initialize empty column in cell metadata
adata.var['gene_annot'] = adata.var_names

# Generate new assignments
for i in genes_annot_dict.keys():
    ind = np.where(pd.Series(adata.var_names).isin([i]))[0]
    adata.var['gene_annot'].iloc[ind] = genes_annot_dict[i]
adata.var['gene_annot'].iloc[ind]
# Out:
# PPBP    PPBP (Megak)
# Name: gene_annot, dtype: object

# %%
# add metadata
meta_cols = ['code', 'nGene', 'nUMI', 'percent.mito', 'Cluster', 'CellType', 'Experiment', 'Method']
barcodes = pd.read_csv(f"{data_path}/barcodes.tsv", header=None, names=['code'])
meta_data = pd.read_csv(f"{data_path}/GSE132044_meta.txt", skiprows=2, names=meta_cols, index_col='code', sep="\t")
meta_df = barcodes.join(other=meta_data, on=['code'], how='left', sort=False)

adata.obs['CellType'] = meta_df['CellType'].tolist()
adata.obs['Experiment'] = meta_df['Experiment'].tolist()
adata.obs['Method'] = meta_df['Method'].tolist()
meta_df
# Out:
#                                              code   nGene      nUMI  \
# 0                                pbmc1_SM2_Cell_1     NaN       NaN
# 1                              pbmc1_SM2_Cell_107     NaN       NaN
# 2                              pbmc1_SM2_Cell_108  2200.0  437125.0
# 3                              pbmc1_SM2_Cell_115  2438.0  335596.0
# 4                              pbmc1_SM2_Cell_125     NaN       NaN
# ...                                           ...     ...       ...
# 45012  pbmc2_inDrops_1_TAGTCTCT.GAGCCTTA.ATCCGCTA   453.0     717.0
# 45013  pbmc2_inDrops_1_TCCAGAAG.TTATGCGA.TAAGACGG   592.0     938.0
# 45014  pbmc2_inDrops_1_TGAATCCT.GAGCCTTA.CCCAAGCA   406.0     662.0
# 45015  pbmc2_inDrops_1_TGAATCCT.TTATGCGA.CATCTCCC  1001.0    2066.0
# 45016  pbmc2_inDrops_1_TGAGCACA.GAGCCTTA.CGAGTCTG   184.0     253.0
#
#        percent.mito  Cluster                     CellType Experiment  \
# 0               NaN      NaN                          NaN        NaN
# 1               NaN      NaN                          NaN        NaN
# 2          0.029743      0.0             Cytotoxic T cell      pbmc1
# 3          0.031152      0.0             Cytotoxic T cell      pbmc1
# 4               NaN      NaN                          NaN        NaN
# ...             ...      ...                          ...        ...
# 45012      0.097629     11.0  Plasmacytoid dendritic cell      pbmc2
# 45013      0.035181     11.0  Plasmacytoid dendritic cell      pbmc2
# 45014      0.138973     11.0  Plasmacytoid dendritic cell      pbmc2
# 45015      0.055663     11.0  Plasmacytoid dendritic cell      pbmc2
# 45016      0.146245     11.0  Plasmacytoid dendritic cell      pbmc2
#
#            Method
# 0             NaN
# 1             NaN
# 2      Smart-seq2
# 3      Smart-seq2
# 4             NaN
# ...           ...
# 45012     inDrops
# 45013     inDrops
# 45014     inDrops
# 45015     inDrops
# 45016     inDrops
#
# [45017 rows x 8 columns]

# %% [markdown]
# ## Preprocessing

# %%
# lets see whats in adata
adata
# Out:
# AnnData object with n_obs × n_vars = 45017 × 33694
#     obs: 'CellType', 'Experiment', 'Method'
#     var: 'gene_ids', 'gene_annot'

# %%
# filter it for only our method and experiment
adata = adata[adata.obs["Experiment"] == exp_str, :]
adata = adata[adata.obs["Method"] == method_str, :]

adata
# Out:
# View of AnnData object with n_obs × n_vars = 273 × 33694
#     obs: 'CellType', 'Experiment', 'Method'
#     var: 'gene_ids', 'gene_annot'

# %%
sc.pl.highest_expr_genes(adata, n_top=20, )
# Out:
# normalizing counts per cell
#     finished (0:00:00)

# %%
# filter out cells with less than 200 genes and genes expressed in less than 3 cells
sc.pp.filter_cells(adata, min_genes=500)
sc.pp.filter_genes(adata, min_cells=1)
# Out:
# filtered out 10432 genes that are detected in less than 1 cells

# %%
# remove genes with high mitochondrial content
adata.var['mt'] = adata.var_names.str.startswith('MT-')  # annotate the group of mitochondrial genes as 'mt'
sc.pp.calculate_qc_metrics(adata, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)
sc.pl.violin(adata, ['n_genes_by_counts', 'total_counts', 'pct_counts_mt'],
             jitter=0.4, multi_panel=True)
# Out:
# ... storing 'CellType' as categorical
# ... storing 'Experiment' as categorical
# ... storing 'Method' as categorical

# %%
sc.pl.scatter(adata, x='total_counts', y='pct_counts_mt')
sc.pl.scatter(adata, x='total_counts', y='n_genes_by_counts')

# %%
# slice the data based on the plots from above
# remove cells with more than 2500 genes
# remove cells with more than 5% MTgenes
adata = adata[adata.obs.n_genes_by_counts < 4000, :]
adata = adata[adata.obs.pct_counts_mt < 7, :]

# %%
# normalize to 10K counts per cell
sc.pp.normalize_total(adata, target_sum=1e4)

# log data
sc.pp.log1p(adata)

# get high variance genes
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)

# and plot
sc.pl.highly_variable_genes(adata)

# now store the raw version of the data for our use later
adata.raw = adata
adata.write(results_file)
# Out:
# normalizing counts per cell
#     finished (0:00:00)
# extracting highly variable genes
#     finished (0:00:01)
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'means', float vector (adata.var)
#     'dispersions', float vector (adata.var)
#     'dispersions_norm', float vector (adata.var)

# %% [markdown]
# ### Run celltypist

# %%
celltype_pred = celltypist.annotate(adata, model = model_str, majority_voting = True)
# Out:
# 🔬 Input data has 252 cells and 23262 genes
# 🔗 Matching reference genes in the model
# 🧬 1985 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 👀 Can not detect a neighborhood graph, construct one before the over-clustering
# ... as `zero_center=True`, sparse input is densified and may lead to large memory consumption
# computing PCA
#     on highly variable genes
#     with n_comps=50
#     finished (0:00:01)
# computing neighbors
#     using 'X_pca' with n_pcs = 50
# OMP: Info #273: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:03)
# ⛓️ Over-clustering input data with resolution set to 5
# running Leiden clustering
#     finished: found 38 clusters and added
#     'over_clustering', the cluster labels (adata.obs, categorical) (0:00:00)
# 🗳️ Majority voting the predictions
# ✅ Majority voting done!

# %%
celltype_pred.predicted_labels['majority_voting'].value_counts()
# Out:
# CD16+ NK cells                    68
# T cells                           58
# B cells                           47
# MAIT cells                        32
# Classical monocytes               17
# Tem/Effector cytotoxic T cells    10
# Helper T cells                     5
# Naive B cells                      5
# Non-classical monocytes            5
# Double-positive thymocytes         3
# Cytotoxic T cells                  2
# Name: majority_voting, dtype: int64

# %%
from matplotlib import pyplot as plt 
import numpy as np  

maxValues = celltype_pred.probability_matrix.max(axis = 1)
hist, bins = np.histogram(maxValues)
plt.hist(maxValues, bins = bins) 
plt.title("Distribution of Top predictions") 
plt.show()

# %%
# now process the counts further for doing DE 
# analysis and the cell clustering
adata = celltype_pred.to_adata()
adata = adata[:, adata.var.highly_variable]

# regress out the signal
sc.pp.regress_out(adata, ['total_counts', 'pct_counts_mt'])

# scale the genes
sc.pp.scale(adata, max_value=10)
# Out:
# regressing out ['total_counts', 'pct_counts_mt']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:36)

# %% [markdown]
# ## PCA

# %%
sc.tl.pca(adata, svd_solver='arpack')
sc.pl.pca(adata, color='CST3')
# Out:
# computing PCA
#     on highly variable genes
#     with n_comps=50
#     finished (0:00:00)

# %%
sc.pl.pca_variance_ratio(adata, log=True)

# %%
# save results
adata.write(results_file)

# %% [markdown]
# ## Compute and embed neighborhood graph

# %%
# valculate neighborhood graph
sc.pp.neighbors(adata)

# make umap
sc.tl.umap(adata)
# Out:
# computing neighbors
#     using 'X_pca' with n_pcs = 50
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:00)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:01)

# %%
# plot some markers of the RAW data
sc.pl.umap(adata, color=['CST3', 'NKG7', 'PPBP'])

# %% [markdown]
# ## Cluster the neighborhood graph

# %%
# lets use Leiden clustering
sc.tl.leiden(adata)
sc.pl.umap(adata, color=['leiden', 'CST3', 'NKG7'])

# save
adata.write(results_file)
# Out:
# running Leiden clustering
#     finished: found 5 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:00)

# %%
sc.pl.umap(adata, color=['leiden'])

# %%
sc.pl.umap(adata, color=['CellType'])

# %%
adata.obs['celltypist'] = celltype_pred.predicted_labels['majority_voting']
sc.pl.umap(adata, color=['CellType', 'celltypist'])

# %%
compare_ct = adata.obs[['celltypist', 'CellType']].groupby(['celltypist', 'CellType'])
compare_ct = compare_ct.size()
compare_ct.unstack()
# Out:
# CellType                        B cell  CD4+ T cell  CD14+ monocyte  \
# celltypist
# B cells                             47            0               0
# CD16+ NK cells                       0            6               0
# Classical monocytes                  0            0              17
# Cytotoxic T cells                    0            0               0
# Double-positive thymocytes           0            0               0
# Helper T cells                       0            3               0
# MAIT cells                           0            0               0
# Naive B cells                        5            0               0
# Non-classical monocytes              0            0               0
# T cells                              1           41               0
# Tem/Effector cytotoxic T cells       0            2               0
#
# CellType                        CD16+ monocyte  Cytotoxic T cell  \
# celltypist
# B cells                                      0                 0
# CD16+ NK cells                               0                17
# Classical monocytes                          0                 0
# Cytotoxic T cells                            0                 2
# Double-positive thymocytes                   0                 3
# Helper T cells                               0                 2
# MAIT cells                                   0                29
# Naive B cells                                0                 0
# Non-classical monocytes                      5                 0
# T cells                                      0                16
# Tem/Effector cytotoxic T cells               0                 6
#
# CellType                        Natural killer cell
# celltypist
# B cells                                           0
# CD16+ NK cells                                   45
# Classical monocytes                               0
# Cytotoxic T cells                                 0
# Double-positive thymocytes                        0
# Helper T cells                                    0
# MAIT cells                                        3
# Naive B cells                                     0
# Non-classical monocytes                           0
# T cells                                           0
# Tem/Effector cytotoxic T cells                    2
